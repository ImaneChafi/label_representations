# %% [markdown]
# # Setup

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/ImaneChafi/label_representations
# Out:
# Cloning into 'label_representations'...
# remote: Enumerating objects: 246, done.
# remote: Counting objects: 100% (246/246), done.
# remote: Compressing objects: 100% (213/213), done.
# remote: Total 246 (delta 35), reused 225 (delta 23), pack-reused 0
# Receiving objects: 100% (246/246), 103.42 MiB | 13.01 MiB/s, done.
# Resolving deltas: 100% (35/35), done.

# %%
# %cd label_representations
# !git pull
# Out:
# [Errno 2] No such file or directory: 'label_representations'
# /content/label_representations
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 36 (delta 6), reused 35 (delta 5), pack-reused 0
# Unpacking objects: 100% (36/36), done.
# From https://github.com/ImaneChafi/label_representations
#  * [new branch]      main       -> origin/main
# There is no tracking information for the current branch.
# Please specify which branch you want to merge with.
# See git-pull(1) for details.
#
#     git pull <remote> <branch>
#
# If you wish to set tracking information for this branch you can do so with:
#
#     git branch --set-upstream-to=origin/<branch> main

# %%
! git branch --set-upstream-to=origin/<branch> main
# Out:
# /bin/bash: branch: No such file or directory

# %%
# !pip install torch
# !pip install torchtoolbox
# Out:
# ...
#      |████████████████████████████████| 84 kB 2.5 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 24.4 MB/s
# ...
#      |████████████████████████████████| 596 kB 52.6 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 56.6 MB/s
# ...
#      |████████████████████████████████| 895 kB 77.3 MB/s
# ...
#      |████████████████████████████████| 61 kB 445 kB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %% [markdown]
# # Running

# %% [markdown]
# ## ResNet110

# %% [markdown]
# ### Original Labels

# %% [markdown]
# #### Category Labels

# %%
# 1 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 1
# Out:
# Start training 1% cifar10 category model with manual seed 7 and model resnet110.
# Best model location: outputs/chantel/1percent/less/cifar10/level1/seed7/resnet110/model_category/category_seed7_resnet110_best_model.pth.
# Checkpoint location: outputs/chantel/1percent/less/cifar10/level1/seed7/resnet110/model_category/category_seed7_resnet110_checkpoint.pth.
# Log location: outputs/chantel/1percent/less/log/cifar10_less_data_category_log.csv.
# Snapshots location: outputs/chantel/1percent/less/cifar10/level1/seed7/resnet110/model_category/snapshots
# Files already downloaded and verified
# ...

# %%
# 2 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 2
# Out:
# Start training 2% cifar10 category model with manual seed 7 and model resnet110.
# Best model location: outputs/chantel/1percent/less/cifar10/level2/seed7/resnet110/model_category/category_seed7_resnet110_best_model.pth.
# Checkpoint location: outputs/chantel/1percent/less/cifar10/level2/seed7/resnet110/model_category/category_seed7_resnet110_checkpoint.pth.
# Log location: outputs/chantel/1percent/less/log/cifar10_less_data_category_log.csv.
# Snapshots location: outputs/chantel/1percent/less/cifar10/level2/seed7/resnet110/model_category/snapshots
# Files already downloaded and verified
# ...

# %%
# 4 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 4
# Out:
# Start training 4% cifar10 category model with manual seed 7 and model resnet110.
# Best model location: outputs/chantel/1percent/less/cifar10/level4/seed7/resnet110/model_category/category_seed7_resnet110_best_model.pth.
# Checkpoint location: outputs/chantel/1percent/less/cifar10/level4/seed7/resnet110/model_category/category_seed7_resnet110_checkpoint.pth.
# Log location: outputs/chantel/1percent/less/log/cifar10_less_data_category_log.csv.
# Snapshots location: outputs/chantel/1percent/less/cifar10/level4/seed7/resnet110/model_category/snapshots
# Files already downloaded and verified
# ...

# %%
# 8 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/baseline --seed 7 --label category --level 8

# %%
# 10 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/baseline --seed 7 --label category --level 10

# %%
# 20 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/baseline --seed 7 --label category --level 20

# %% [markdown]
# #### Speech Labels

# %%
# 1 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 1
# Out:
# Start training 1% cifar10 speech model with manual seed 7 and model resnet110.
# Best model location: outputs/chantel/1percent/less/cifar10/level1/seed7/resnet110/model_speech/speech_seed7_resnet110_best_model.pth.
# Checkpoint location: outputs/chantel/1percent/less/cifar10/level1/seed7/resnet110/model_speech/speech_seed7_resnet110_checkpoint.pth.
# Log location: outputs/chantel/1percent/less/log/cifar10_less_data_speech_log.csv.
# Snapshots location: outputs/chantel/1percent/less/cifar10/level1/seed7/resnet110/model_speech/snapshots
# Files already downloaded and verified
# ...

# %%
# 2 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 2
# Out:
# Start training 2% cifar10 speech model with manual seed 7 and model resnet110.
# Best model location: outputs/chantel/1percent/less/cifar10/level2/seed7/resnet110/model_speech/speech_seed7_resnet110_best_model.pth.
# Checkpoint location: outputs/chantel/1percent/less/cifar10/level2/seed7/resnet110/model_speech/speech_seed7_resnet110_checkpoint.pth.
# Log location: outputs/chantel/1percent/less/log/cifar10_less_data_speech_log.csv.
# Snapshots location: outputs/chantel/1percent/less/cifar10/level2/seed7/resnet110/model_speech/snapshots
# Files already downloaded and verified
# ...

# %%
# 4 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 4
# Out:
# Start training 4% cifar10 speech model with manual seed 7 and model resnet110.
# Best model location: outputs/chantel/1percent/less/cifar10/level4/seed7/resnet110/model_speech/speech_seed7_resnet110_best_model.pth.
# Checkpoint location: outputs/chantel/1percent/less/cifar10/level4/seed7/resnet110/model_speech/speech_seed7_resnet110_checkpoint.pth.
# Log location: outputs/chantel/1percent/less/log/cifar10_less_data_speech_log.csv.
# Snapshots location: outputs/chantel/1percent/less/cifar10/level4/seed7/resnet110/model_speech/snapshots
# Files already downloaded and verified
# ...

# %%
# 8 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/baseline --seed 7 --label speech --level 8

# %%
# 10 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/baseline --seed 7 --label speech --level 10

# %%
# 20 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/baseline --seed 7 --label speech --level 20

# %% [markdown]
# ### Chantel Labels

# %% [markdown]
# #### Category Labels

# %%
# 1 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 1
# Out:
# Start training 1% cifar10 category model with manual seed 7 and model resnet110.
# Best model location: outputs/chantel/1percent/less/cifar10/level1/seed7/resnet110/model_category/category_seed7_resnet110_best_model.pth.
# Checkpoint location: outputs/chantel/1percent/less/cifar10/level1/seed7/resnet110/model_category/category_seed7_resnet110_checkpoint.pth.
# Log location: outputs/chantel/1percent/less/log/cifar10_less_data_category_log.csv.
# Snapshots location: outputs/chantel/1percent/less/cifar10/level1/seed7/resnet110/model_category/snapshots
# Files already downloaded and verified
# ...

# %%
# 2 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 2
# Out:
# Start training 2% cifar10 category model with manual seed 7 and model resnet110.
# Best model location: outputs/chantel/1percent/less/cifar10/level2/seed7/resnet110/model_category/category_seed7_resnet110_best_model.pth.
# Checkpoint location: outputs/chantel/1percent/less/cifar10/level2/seed7/resnet110/model_category/category_seed7_resnet110_checkpoint.pth.
# Log location: outputs/chantel/1percent/less/log/cifar10_less_data_category_log.csv.
# Snapshots location: outputs/chantel/1percent/less/cifar10/level2/seed7/resnet110/model_category/snapshots
# Files already downloaded and verified
# ...

# %%
# 4 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 4
# Out:
# Start training 4% cifar10 category model with manual seed 7 and model resnet110.
# Best model location: outputs/chantel/1percent/less/cifar10/level4/seed7/resnet110/model_category/category_seed7_resnet110_best_model.pth.
# Checkpoint location: outputs/chantel/1percent/less/cifar10/level4/seed7/resnet110/model_category/category_seed7_resnet110_checkpoint.pth.
# Log location: outputs/chantel/1percent/less/log/cifar10_less_data_category_log.csv.
# Snapshots location: outputs/chantel/1percent/less/cifar10/level4/seed7/resnet110/model_category/snapshots
# Files already downloaded and verified
# ...

# %%
# 8 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 8
# Out:
# Start training 8% cifar10 category model with manual seed 7 and model resnet110.
# Best model location: outputs/chantel/1percent/less/cifar10/level8/seed7/resnet110/model_category/category_seed7_resnet110_best_model.pth.
# Checkpoint location: outputs/chantel/1percent/less/cifar10/level8/seed7/resnet110/model_category/category_seed7_resnet110_checkpoint.pth.
# Log location: outputs/chantel/1percent/less/log/cifar10_less_data_category_log.csv.
# Snapshots location: outputs/chantel/1percent/less/cifar10/level8/seed7/resnet110/model_category/snapshots
# Files already downloaded and verified
# ...

# %%
# 10 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 10

# %%
# 20 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 20

# %% [markdown]
# #### Speech Labels

# %%
# 1 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 1
# Out:
# Start training 1% cifar10 speech model with manual seed 7 and model resnet110.
# Best model location: outputs/chantel/1percent/less/cifar10/level1/seed7/resnet110/model_speech/speech_seed7_resnet110_best_model.pth.
# Checkpoint location: outputs/chantel/1percent/less/cifar10/level1/seed7/resnet110/model_speech/speech_seed7_resnet110_checkpoint.pth.
# Log location: outputs/chantel/1percent/less/log/cifar10_less_data_speech_log.csv.
# Snapshots location: outputs/chantel/1percent/less/cifar10/level1/seed7/resnet110/model_speech/snapshots
# Files already downloaded and verified
# ...

# %%
# 2 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 2
# Out:
# Start training 2% cifar10 speech model with manual seed 7 and model resnet110.
# Best model location: outputs/chantel/1percent/less/cifar10/level2/seed7/resnet110/model_speech/speech_seed7_resnet110_best_model.pth.
# Checkpoint location: outputs/chantel/1percent/less/cifar10/level2/seed7/resnet110/model_speech/speech_seed7_resnet110_checkpoint.pth.
# Log location: outputs/chantel/1percent/less/log/cifar10_less_data_speech_log.csv.
# Snapshots location: outputs/chantel/1percent/less/cifar10/level2/seed7/resnet110/model_speech/snapshots
# Files already downloaded and verified
# ...

# %%
# 4 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 4
# Out:
# Start training 4% cifar10 speech model with manual seed 7 and model resnet110.
# Best model location: outputs/chantel/1percent/less/cifar10/level4/seed7/resnet110/model_speech/speech_seed7_resnet110_best_model.pth.
# Checkpoint location: outputs/chantel/1percent/less/cifar10/level4/seed7/resnet110/model_speech/speech_seed7_resnet110_checkpoint.pth.
# Log location: outputs/chantel/1percent/less/log/cifar10_less_data_speech_log.csv.
# Snapshots location: outputs/chantel/1percent/less/cifar10/level4/seed7/resnet110/model_speech/snapshots
# Files already downloaded and verified
# ...

# %%
# 8 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 8
# Out:
# Start training 8% cifar10 speech model with manual seed 7 and model resnet110.
# Best model location: outputs/chantel/1percent/less/cifar10/level8/seed7/resnet110/model_speech/speech_seed7_resnet110_best_model.pth.
# Checkpoint location: outputs/chantel/1percent/less/cifar10/level8/seed7/resnet110/model_speech/speech_seed7_resnet110_checkpoint.pth.
# Log location: outputs/chantel/1percent/less/log/cifar10_less_data_speech_log.csv.
# Snapshots location: outputs/chantel/1percent/less/cifar10/level8/seed7/resnet110/model_speech/snapshots
# Files already downloaded and verified
# ...

# %%
# 10 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 10

# %%
# 20 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 20

# %% [markdown]
# ## ResNet32

# %% [markdown]
# ### Original Labels

# %% [markdown]
# #### Category Labels

# %%
# 1 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 1
# Out:
# Start training 1% cifar10 category model with manual seed 7 and model resnet110.
# Best model location: outputs/chantel/1percent/less/cifar10/level1/seed7/resnet110/model_category/category_seed7_resnet110_best_model.pth.
# Checkpoint location: outputs/chantel/1percent/less/cifar10/level1/seed7/resnet110/model_category/category_seed7_resnet110_checkpoint.pth.
# Log location: outputs/chantel/1percent/less/log/cifar10_less_data_category_log.csv.
# Snapshots location: outputs/chantel/1percent/less/cifar10/level1/seed7/resnet110/model_category/snapshots
# Files already downloaded and verified
# ...

# %%
# 2 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 2

# %%
# 4 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 4

# %%
# 8 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 8

# %%
# 10 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 10

# %%
# 20 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 20

# %% [markdown]
# #### Speech Labels

# %%
# 1 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 1

# %%
# 2 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 2

# %%
# 4 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 4

# %%
# 8 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 8

# %%
# 10 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 10

# %%
# 20 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 20

# %% [markdown]
# ### Chantel Labels

# %% [markdown]
# #### Category Labels

# %%
# 1 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 1

# %%
# 2 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 2

# %%
# 4 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 4

# %%
# 8 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 8

# %%
# 10 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 10

# %%
# 20 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 20

# %% [markdown]
# #### Speech Labels

# %%
# 1 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 1

# %%
# 2 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 2

# %%
# 4 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 4

# %%
# 8 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 8

# %%
# 10 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 10

# %%
# 20 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 20

# %% [markdown]
# ## VGG19

# %% [markdown]
# ### Original Labels

# %% [markdown]
# #### Category Labels

# %%
# 1 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 1
# Out:
# Start training 1% cifar10 category model with manual seed 7 and model resnet110.
# Best model location: outputs/chantel/1percent/less/cifar10/level1/seed7/resnet110/model_category/category_seed7_resnet110_best_model.pth.
# Checkpoint location: outputs/chantel/1percent/less/cifar10/level1/seed7/resnet110/model_category/category_seed7_resnet110_checkpoint.pth.
# Log location: outputs/chantel/1percent/less/log/cifar10_less_data_category_log.csv.
# Snapshots location: outputs/chantel/1percent/less/cifar10/level1/seed7/resnet110/model_category/snapshots
# Files already downloaded and verified
# ...

# %%
# 2 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 2

# %%
# 4 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 4

# %%
# 8 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 8

# %%
# 10 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 10

# %%
# 20 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 20

# %% [markdown]
# #### Speech Labels

# %%
# 1 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 1

# %%
# 2 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 2

# %%
# 4 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 4

# %%
# 8 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 8

# %%
# 10 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 10

# %%
# 20 % of data
# !python train.py --model resnet110 --dataset cifar10 --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 20

# %% [markdown]
# ### Chantel Labels

# %% [markdown]
# #### Category Labels

# %%
# 1 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 1

# %%
# 2 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 2

# %%
# 4 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 4

# %%
# 8 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 8

# %%
# 10 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 10

# %%
# 20 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label category --level 20

# %% [markdown]
# #### Speech Labels

# %%
# 1 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 1

# %%
# 2 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 2

# %%
# 4 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 4

# %%
# 8 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 8

# %%
# 10 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 10

# %%
# 20 % of data
# !python train.py --model resnet110 --dataset cifar10 --label_dir ./labels/label_files/chantel --base_dir ./outputs/chantel/1percent --seed 7 --label speech --level 20

# %% [markdown]
# # Save

# %%
# !git add .
# !git commit -m "ResNet110 trained on less data with chantel and original speech labels, 4% resNet110"
# Out:
# On branch main
# nothing to commit, working tree clean

# %%
uname = "name"
# !git config --global user.email "name@gmail.com"
# !git config --global user.name "name"
token = "token"

# !git remote remove origin
# !git remote add origin https://$uname:$token@github.com/ImaneChafi/label_representations

# %%
! git status
# Out:
# On branch main
# nothing to commit, working tree clean

# %%
! git pull origin main
# Out:
# From https://github.com/ImaneChafi/label_representations
#  * branch            main       -> FETCH_HEAD
# hint: Waiting for your editor to close the file... error: unable to start editor 'editor'
# Not committing merge; use 'git commit' to complete the merge.

# %%
! git checkout main
# Out:
# Switched to branch 'main'
